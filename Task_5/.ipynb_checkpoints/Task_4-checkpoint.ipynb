# %% [markdown]
# Sales prediction means predicting how much of a product people will buy based on factors
# such as the amount you spend to advertise your product, the segment of people you
# advertise for, or the platform you are advertising on about your product.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

# %%
df=pd.read_csv('Advertising.csv')

# %%
df.shape
# Out:
# (200, 5)

# %%
df.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# Radio         0
# Newspaper     0
# Sales         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
sns.pairplot(df,x_vars=['TV'],y_vars=['Sales'],height= 7,aspect=1.5,kind='reg')
plt.suptitle('Advertising Budget vs Sales', y=1.0)
plt.show()

# %%
sns.pairplot(df,x_vars=['Radio'],y_vars=['Sales'],height= 7,aspect=1.5,kind='scatter')
plt.suptitle('Advertising Budget vs Sales', y=1.0)
plt.show()

# %%
sns.pairplot(df,x_vars=['Newspaper'],y_vars=['Sales'],height= 7,aspect=1.5,kind='scatter')
plt.suptitle('Advertising Budget vs Sales', y=1.0)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(),annot=True)
plt.title("Heatmap for the correlations")
plt.show()

# %%
X=df[['TV','Radio','Newspaper']]
Y=df['Sales']
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.4,random_state=42)

# %%
model= LinearRegression()
model.fit(X_train,Y_train)
Y_pred=model.predict(X_test)

# %%
mse=mean_squared_error(Y_test,Y_pred)
rmse=np.sqrt(mse)
r2=r2_score(Y_test,Y_pred)

# %%
print(f"Linear Regression nModel Evaluation Metrics:")
print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")
print(f"R-squared (R2 Score): {r2:.2f}")
# Out:
# Linear Regression nModel Evaluation Metrics:
# Mean Squared Error (MSE): 3.43
# Root Mean Squared Error (RMSE): 1.85
# R-squared (R2 Score): 0.86

# %%
plt.figure(figsize=(10, 6))
plt.scatter(Y_test, Y_pred, color='blue', alpha=0.6)
plt.plot([Y.min(), Y.max()], [Y.min(), Y.max()], 'r--', lw=2)
plt.xlabel('Actual Sales')
plt.ylabel('Predicted Sales')
plt.title('Actual vs Predicted Sales')
plt.show()
